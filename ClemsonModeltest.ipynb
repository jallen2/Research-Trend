# %%
from gensim import corpora, models, similarities
from collections import defaultdict
import gensim
from bs4 import BeautifulSoup


#dictionary for probability table
table = {}

#All Ids file
file01 = open('cu_IDs.txt', 'r')
ID = file01.readlines()

#Doctorates and Divisions file
file02 = open('cu_doc_div.txt', 'r')
dict_div = file02.readlines()
    
    
#20% arrays convertion to vectors 
doc001 = ["NULL"]
doc002 = ["NULL"]
doc003 = ["NULL"]
doc004 = ["NULL"]
doc005 = ["NULL"]


#Probability arrays and holder 
box = []
box1 = ["NULL"]
box2 = ["NULL"]
box3 = ["NULL"]
box4 = ["NULL"]
box5 = ["NULL"]

#increment variable for 20% arrays
a = 0
b = 0
c = 0
d = 0
e = 0 
f = 0
num = 0 
num1 = 0
count = 0


# 20% abstract files
file1 = open('cu_test_doc1.txt', 'r')
doc1 = file1.readlines()
file2 = open('cu_test_doc2.txt', 'r')
doc2 = file2.readlines()
file3 = open('cu_test_doc3.txt', 'r')
doc3 = file3.readlines()
file4 = open('cu_test_doc4.txt', 'r')
doc4 = file4.readlines()
file5 = open('cu_test_doc5.txt', 'r')
doc5 = file5.readlines()

# 20% Directorate/Division files
file10 = open('cu_test_dir_div1.txt', 'r')
dd1 = file1.readlines()
file20 = open('cu_test_dir_div2.txt', 'r')
dd2 = file2.readlines()
file30 = open('cu_test_dir_div3.txt', 'r')
dd3 = file3.readlines()
file40 = open('cu_test_dir_div4.txt', 'r')
dd4 = file4.readlines()
file50 = open('cu_test_dir_div5.txt', 'r')
dd5 = file5.readlines()


#Load 80% Dictionary 
dictionary1 = corpora.Dictionary.load('/tmp/cu_dict1.dict')
dictionary2 = corpora.Dictionary.load('/tmp/cu_dict2.dict')
dictionary3 = corpora.Dictionary.load('/tmp/cu_dict3.dict')
dictionary4 = corpora.Dictionary.load('/tmp/cu_dict4.dict')
dictionary5 = corpora.Dictionary.load('/tmp/cu_dict5.dict')

#Load 80% Corpus 
corpus1 = corpora.MmCorpus('/tmp/cu_corpus1.mm')
corpus2 = corpora.MmCorpus('/tmp/cu_corpus2.mm')
corpus3 = corpora.MmCorpus('/tmp/cu_corpus3.mm')
corpus4 = corpora.MmCorpus('/tmp/cu_corpus4.mm')
corpus5 = corpora.MmCorpus('/tmp/cu_corpus5.mm')

#Load 80% lda model 
lda1 = models.LdaModel.load('/tmp/CuModel_1.lda')
lda2 = models.LdaModel.load('/tmp/CuModel_2.lda')
lda3 = models.LdaModel.load('/tmp/CuModel_3.lda')
lda4 = models.LdaModel.load('/tmp/CuModel_4.lda')
lda5 = models.LdaModel.load('/tmp/CuModel_5.lda')


for x in range(20):
    if num == 0: 
        doc001[0] = dictionary1.doc2bow(doc1[num].lower().split())
        doc002[0] = dictionary2.doc2bow(doc2[num].lower().split())
        doc003[0] = dictionary3.doc2bow(doc3[num].lower().split())
        doc004[0] = dictionary4.doc2bow(doc4[num].lower().split())
        num += 1 
    else:
        holder1 = dictionary1.doc2bow(doc1[num].lower().split())
        doc001.append(holder1)
        holder2 = dictionary2.doc2bow(doc2[num].lower().split())
        doc002.append(holder2)
        holder3 = dictionary3.doc2bow(doc3[num].lower().split())
        doc003.append(holder3)
        holder4 = dictionary4.doc2bow(doc4[num].lower().split())
        doc004.append(holder4)
        num += 1 
for y in range(18):
    if num1 == 0: 
        doc005[0] = dictionary5.doc2bow(doc5[num1].lower().split())
        num1 += 1 
    else: 
        holder5 = dictionary5.doc2bow(doc5[num1].lower().split())
        doc005.append(holder5)
        num1 += 1
    

for n in range(20):
    if a == 0: 
        D = doc001[0] #0-19 --> 20  
        box1[0] = lda1[D]
        a += 1
    else: 
        box1.append(lda1[doc001[n]])
for n in range(20):
    if b == 0: 
        D = doc002[0] #0-19 --> 20  
        box2[0] = lda2[D]
        b += 1
    else: 
        box2.append(lda2[doc002[n]])
for n in range(20):
    if c == 0: 
        D = doc003[0] #0-19 --> 20  
        box3[0] = lda3[D]
        c += 1
    else: 
        box3.append(lda3[doc003[n]])
for n in range(20):
    if d == 0: 
        D = doc004[0] #0-19 --> 20  
        box4[0] = lda4[D]
        d += 1
    else: 
        box4.append(lda4[doc004[n]])
for n in range(18):
    if e == 0: 
        D = doc005[0] #0-17 --> 18  
        box5[0] = lda5[D]
        e += 1
    else: 
        box5.append(lda5[doc005[n]])

box = box1 + box2 + box3 + box4 + box5

for probs in range(98):
    table[ID[probs]] = box[probs]

for k,v in table.items():
    count += 1 
    if count == 1:
        print('**********Model 1 Start**********\n')
    print(str(count)+')','xml ID:',k,'\n',v,'\n')
    if count == 20: 
        print('**********Model 2 Start**********\n')
    if count == 40: 
        print('**********Model 3 Start**********\n')
    if count == 60: 
        print('**********Model 4 Start**********\n')
    if count == 80: 
        print('**********Model 5 Start**********\n')
    if count == 98:
        print('***********End of Output*********')
# Out:
# **********Model 1 Start**********
#
# 1) xml ID: 1560300
#
#  [(1, 0.018493223286796322), (5, 0.12981422701426032), (7, 0.086648201241953771), (8, 0.06616965771687576), (9, 0.14541191651913871), (11, 0.096875319853268888), (12, 0.036199620475446767), (14, 0.08374632460320286), (16, 0.059626370384143333), (17, 0.051997433596439109), (18, 0.15444493110296462), (21, 0.0671517215734381)]
#
# 2) xml ID: 1602451
#
#  [(0, 0.082788552760726594), (2, 0.074625782091336856), (4, 0.073290397088433254), (5, 0.086168421578294865), (7, 0.024496827008192973), (8, 0.19599396585550929), (10, 0.059887348659282393), (11, 0.068909190188960467), (14, 0.020898281946553184), (15, 0.017180424483999934), (16, 0.053382052968887234), (17, 0.076002983550000611), (22, 0.15636283310982005)]
#
# 3) xml ID: 1541944
#
#  [(0, 0.064934778225378742), (1, 0.058780308400554634), (2, 0.061723346615090983), (3, 0.018558299303078663), (5, 0.020291553099124102), (9, 0.019777567816819622), (10, 0.12790661783127216), (12, 0.022410613579960978), (13, 0.08919518614241069), (15, 0.034419384221810165), (17, 0.051680200439563215), (18, 0.22002443121888646), (20, 0.07137283316925315), (22, 0.070933994980360252), (23, 0.020575058079742102), (24, 0.045285649361609684)]
#
# 4) xml ID: 1638888
#
#
# 94) xml ID: 1642143
#
#  [(3, 0.10065881720546721), (7, 0.10644787995951535), (8, 0.048125744989425755), (9, 0.022119865812942435), (10, 0.030211883811829134), (13, 0.026626422904534611), (15, 0.16180152465763051), (16, 0.045007257208858828), (17, 0.021466665794963955), (18, 0.01945563014973984), (21, 0.0475329796551862), (22, 0.30461107887465205), (23, 0.062577605618265336)]
#
# 95) xml ID: 1502392
#
#  [(1, 0.10915630269557357), (2, 0.063468183002674997), (3, 0.030701350339844453), (4, 0.32146280781285458), (7, 0.0233744363651163), (9, 0.056420983145850902), (11, 0.05515344690571606), (14, 0.13196828372596994), (15, 0.066104059526665968), (16, 0.069864269119842823), (23, 0.010839047268508093), (24, 0.057189309429352637)]
#
# 96) xml ID: 1502293
#
#  [(0, 0.035315467723420618), (2, 0.052968539462712488), (4, 0.022768270601758466), (8, 0.064545759979190265), (14, 0.17962898890194032), (15, 0.53666880235907244), (20, 0.031488530632356619), (21, 0.039235410449459142), (24, 0.024223740800561114)]
#
# 97) xml ID: 1644552
#
#  [(2, 0.05138404944569145), (7, 0.48611705953889583), (8, 0.063546052704467657), (15, 0.1097890366906121), (16, 0.04042978838897289), (17, 0.034045520302953207), (20, 0.025695730460723251), (22, 0.15189792459199788), (23, 0.026026472224609274)]
#
# 98) xml ID: 1522751
#
#  [(0, 0.058775278730499009), (4, 0.23717439725382858), (5, 0.03958895136715819), (8, 0.05206320173652066), (9, 0.084905620165875398), (10, 0.12252972002722433), (13, 0.041378835695453996), (15, 0.061838387223781918), (18, 0.088835061608119048), (19, 0.012537638091945122), (20, 0.16721306468722855), (24, 0.029065355222755773)]
#
# ***********End of Output*********

# %%
from gensim import corpora, models, similarities
from collections import defaultdict
import gensim


top1 = []
top2 = []
top3 = []
top4 = []
top5 = []
topics = [top1,top2,top3,top4,top5]
    

lda1 = models.LdaModel.load('/tmp/CuModel_1.lda')
lda2 = models.LdaModel.load('/tmp/CuModel_2.lda')
lda3 = models.LdaModel.load('/tmp/CuModel_3.lda')
lda4 = models.LdaModel.load('/tmp/CuModel_4.lda')
lda5 = models.LdaModel.load('/tmp/CuModel_5.lda')

for i in range(25): 
    top1.append(lda1.print_topic(i))
    top2.append(lda2.print_topic(i))
    top3.append(lda3.print_topic(i))
    top4.append(lda4.print_topic(i))
    top5.append(lda5.print_topic(i))
    
lda1.print_topics(25)
# Out:
# [(0,
#   '0.010*tactons + 0.010*information + 0.010*organizational + 0.010*faculty + 0.010*stem + 0.008*support + 0.008*multimodal + 0.008*equity + 0.008*women + 0.008*advance'),
#  (1,
#   '0.014*power + 0.012*systems + 0.010*energy + 0.010*performance + 0.010*processing + 0.010*ceramic + 0.010*center + 0.008*technologies + 0.008*materials + 0.008*measurement'),
#  (2,
#   '0.016*mercury + 0.014*education + 0.011*carbon + 0.011*coastal + 0.010*study + 0.009*learning + 0.008*outcomes + 0.008*flooding + 0.008*extreme + 0.008*programs'),
#  (3,
#   '0.020*material + 0.018*design + 0.016*development + 0.014*faculty + 0.010*workshop + 0.010*graduate + 0.010*stem + 0.010*materials + 0.009*undergraduate + 0.009*students'),
#  (4,
#   '0.009*design + 0.009*cyberbullying + 0.008*engineering + 0.006*grain + 0.006*systems + 0.006*processes + 0.006*steel + 0.006*membrane + 0.005*modeling + 0.005*ambic'),
#  (5,
#   '0.012*heat + 0.010*students + 0.009*commercialization + 0.008*energy + 0.008*generation + 0.008*power + 0.007*graduate + 0.006*technology + 0.006*potential + 0.006*theory'),
#  (6,
#   '0.018*vehicle + 0.016*system + 0.014*control + 0.009*based + 0.009*detection + 0.009*algorithms + 0.009*cyber-attack + 0.007*systems + 0.007*communication + 0.007*security'),
#  (7,
#   '0.022*anions + 0.011*receptors + 0.008*interactions + 0.007*simulation + 0.006*molecular + 0.006*students + 0.006*units + 0.006*should + 0.006*catalyst + 0.006*liquid'),
#  (8,
#   '0.013*water + 0.013*network + 0.010*science + 0.009*homes + 0.008*security + 0.008*studies + 0.007*data + 0.006*technology + 0.006*energy + 0.006*infrastructure'),
#  (9,
#   '0.013*water + 0.013*quality + 0.011*implant + 0.010*materials + 0.010*charging + 0.010*network + 0.009*data + 0.008*urban + 0.008*optimization + 0.008*artificial'),
#  (10,
#   '0.018*theory + 0.018*spaces + 0.011*buildings + 0.011*signals + 0.009*building + 0.009*mathematical + 0.009*de + 0.009*branges + 0.007*design + 0.007*analysis'),
#  (11,
#   '0.010*microwave + 0.009*students + 0.008*yeast + 0.008*dynamics + 0.007*technology + 0.007*properties + 0.007*chemical + 0.007*experience + 0.007*ionic + 0.007*polymers'),
#  (12,
#   '0.022*data + 0.015*layer + 0.015*surface + 0.015*provenance + 0.010*distributed + 0.010*systems + 0.007*similarity + 0.007*turbulence + 0.007*mmo + 0.007*monin-obukhov'),
#  (13,
#   '0.010*infrastructure + 0.010*program + 0.009*systems + 0.007*simulation + 0.007*engineering + 0.007*model + 0.007*critical + 0.007*students + 0.007*technology + 0.007*emerging'),
#  (14,
#   '0.011*students + 0.008*science + 0.008*training + 0.008*cybersecurity + 0.006*internet + 0.006*program + 0.006*engineering + 0.006*development + 0.006*infrastructure + 0.006*national'),
#  (15,
#   '0.011*students + 0.010*stem + 0.010*conference + 0.007*graduate + 0.007*latency + 0.006*network + 0.005*highly + 0.005*program + 0.005*grades + 0.005*middle'),
#  (16,
#   '0.017*nucleation + 0.017*ice + 0.012*process + 0.010*heterogeneous + 0.009*curing + 0.009*molecular + 0.009*materials + 0.007*students + 0.007*processing + 0.007*biobased'),
#  (17,
#   '0.019*sustainability + 0.016*learning + 0.015*courses + 0.012*faculty + 0.011*modules + 0.011*development + 0.010*different + 0.010*disposal + 0.009*stand-alone + 0.008*module'),
#  (18,
#   '0.028*computing + 0.013*consortium + 0.013*national + 0.013*campuses + 0.009*carc + 0.009*campus + 0.009*capabilities + 0.006*expertise + 0.006*facilitation + 0.006*best'),
#  (19,
#   '0.022*geoscience + 0.015*students + 0.009*program + 0.007*develop + 0.007*earpiece + 0.007*undergraduate + 0.007*majors + 0.007*geosciences + 0.006*behaviors + 0.006*health'),
#  (20,
#   '0.014*engineering + 0.011*students + 0.010*mtbe + 0.007*origami + 0.006*microbial + 0.006*model + 0.005*folding + 0.005*ejected + 0.004*graduate + 0.004*specific'),
#  (21,
#   '0.018*privacy + 0.010*production + 0.008*team + 0.008*light + 0.008*capacity + 0.008*existing + 0.008*users + 0.007*puritm + 0.007*manufacturing + 0.006*membrane'),
#  (22,
#   '0.010*properties + 0.010*novel + 0.010*sensitivity + 0.008*development + 0.008*cell + 0.008*nps + 0.008*cells + 0.008*biological + 0.007*corona + 0.007*np'),
#  (23,
#   '0.022*amulet + 0.014*applications + 0.014*technology + 0.011*health + 0.011*mhealth + 0.008*wearable + 0.008*platform + 0.006*software + 0.006*life + 0.006*framework'),
#  (24,
#   '0.008*field + 0.007*power + 0.007*students + 0.006*experiences + 0.006*support + 0.005*design + 0.005*systems + 0.005*change + 0.005*capacity + 0.005*lab')]

# %%
from gensim import corpora, models, similarities
from collections import defaultdict
import gensim
from bs4 import BeautifulSoup



#Open the xml file
test_doc = open('2016/1600011.xml','r')

#Store data from xml file 
xml = test_doc.read()

#Convert data to iterable text  
soup = BeautifulSoup(xml,'xml')
    
#find the abstract in the xml file and filter out non-word elements
words = soup.AbstractNarration.string.replace('<br/>','').replace(',','').replace('.','').replace('\n','')

#concatinate the dictorate to its division and add a tab between them 
dic = soup.Directorate.LongName.string  
div = soup.Division.LongName.string
doc_div1 = dic + '\t' + div


#All abstracts file
file = open('cu_tigers.txt','r') 
doc = file.readlines()

#All Ids file
file2 = open('cu_IDs.txt', 'r')
doc2 = file2.readlines()

#Doctorates and Divisions file
file3 = open('cu_doc_div.txt', 'r')
doc3 = file3.readlines()


#load dictionary
dictionary = corpora.Dictionary.load('/tmp/cu_dict.dict')

#load corpus
corpus = corpora.MmCorpus('/tmp/cu_corpus.mm') # comes from the first tutorial, "From strings to vectors"
#Load Model

topic_prob = ["NULL"]
x = 0
number = 1

lda = models.LdaModel.load('/tmp/CuModel.lda')


for word in lda.print_topics(25):
    if x == 0:
        topic_prob[0]=word
        x = x + 1
    else:
        topic_prob.append(words)

for t in topic_prob:
    #print("Topic",number,":",t,"\n")
    number = number + 1
    
#convert new document to vector tuples 
document = dictionary.doc2bow(words.lower().split())
vec_lda = lda[document]


lda.print_topics(25)

# %%
from collections import deque
from gensim import corpora, models, similarities 
from collections import defaultdict
import gensim
import matplotlib.pyplot as plt


# %matplotlib inline

class topic:
    count = 0
    def __init__(self,topic_name):
        self.name = topic_name
        self.abstract = []
        topic.count +=1
    def addlist(self,abstr):
        self.abstract.append(abstr)
    def delete(self):
        topic.count = 0 


# 20% abstract files
file1 = open('cu_test_doc1.txt', 'r')
abs1 = file1.readlines()
file2 = open('cu_test_doc2.txt', 'r')
abs2 = file2.readlines()
file3 = open('cu_test_doc3.txt', 'r')
abs3 = file3.readlines()
file4 = open('cu_test_doc4.txt', 'r')
abs4 = file4.readlines()
file5 = open('cu_test_doc5.txt', 'r')
abs5 = file5.readlines()

# 20% Directorate/Division files
file10 = open('cu_test_dir_div1.txt', 'r')
dd1 = file10.readlines()
file20 = open('cu_test_dir_div2.txt', 'r')
dd2 = file20.readlines()
file30 = open('cu_test_dir_div3.txt', 'r')
dd3 = file30.readlines()
file40 = open('cu_test_dir_div4.txt', 'r')
dd4 = file40.readlines()
file50 = open('cu_test_dir_div5.txt', 'r')
dd5 = file50.readlines()
    
#Load models 80%
lda1 = models.LdaModel.load('/tmp/CuModel_1.lda')
#lda2 = models.LdaModel.load('/tmp/CuModel_2.lda')
#lda3 = models.LdaModel.load('/tmp/CuModel_3.lda')
#lda4 = models.LdaModel.load('/tmp/CuModel_4.lda')
#lda5 = models.LdaModel.load('/tmp/CuModel_5.lda')

#Load 80% Dictionary 
dictionary1 = corpora.Dictionary.load('/tmp/cu_dict1.dict')
#dictionary2 = corpora.Dictionary.load('/tmp/cu_dict2.dict')
#dictionary3 = corpora.Dictionary.load('/tmp/cu_dict3.dict')
#dictionary4 = corpora.Dictionary.load('/tmp/cu_dict4.dict')
#dictionary5 = corpora.Dictionary.load('/tmp/cu_dict5.dict')
 
#Directorates and Divisions files
file = open('cu_doc_div.txt', 'r')
dd = file.readlines()    

#All Abstracts
file2 = open('cu_tigers.txt','r')
abstr = file2.readlines()
 


def dd_compare(test_topic,abst):
    #Directorates and Divisions files
    file = open('cu_doc_div2.txt', 'r')
    dd2 = file.readlines()
    t_file = open('topic_count.txt', 'r')
    num = t_file.read()
    TOPIC_COUNT = int(num)
     
    y = 0
    new_name = 0
    topic.count = 0 
    fcount = 0 
    
    while y != TOPIC_COUNT:
        for x in range(len(test_topic)):
            if test_topic[x] == dd2[y]:
                if new_name == 0: 
                    fcount+=1
                    name["topic{0}".format(fcount)] = topic(dd2[y])#create an object and name it
                    new_name +=1 
                name["topic{0}".format(fcount)].addlist(abst[x])#add abstracts from matches
            if x == len(test_topic)-1:
                if new_name > 0:
                    new_name-=1
                y+=1
#Outputs dd compare when called after dd compare 
def output_printer():
    for x in range(topic.count):
        print(name['topic{0}'.format(x+1)].name)
        for x in name['topic{0}'.format(x+1)].abstract:
            print(x,"\n")
def bagofwords(words,dictionary):
    d = []
    for x in range(len(words)):
        d.append(dictionary.doc2bow(words[x].lower().split()))
    return d 

t_file = open('topic_count.txt', 'r')
TOPIC_COUNT = t_file.read()

#create objects for 20% group 1
dd_compare(dd1,abs1) 

#topic names are topic1, topic2, etc
topic_abs = name["topic2"].abstract
topic_name = name["topic2"].name

print('Topic Name:', topic_name)

print("Topics Represented by 20% group:",topic.count,"\n")

#convert topic abstracts to bag of words 
bow = bagofwords(topic_abs,dictionary1)

vec = lda1[bow[0]]
vec1 = lda1[bow[1]]
#vec2 = lda1[bow[2]]

print("Abstract 1 Distribution:")
print(vec)
print("\nAbstract 2 Distribution:")
print(vec1)
#print("\nAbstract 3 Distribution:")
#print(vec2)

plt.plot([x[0] for x in vec],[x[1] for x in vec])
plt.plot([x[0] for x in vec1],[x[1] for x in vec1])
#plt.plot([x[0] for x in vec2],[x[1] for x in vec2])
plt.xlabel('Topics (0-'+ TOPIC_COUNT + ')')
plt.ylabel('Probability of Correlation with Topics')
plt.title('Topic Model Correlation Chart')

plt.show

      
#dd_compare(dd2,abs2) #create objects for 20% group 2

#dd_compare(dd3,abs3) #create objects for 20% group 3

#dd_compare(dd4,abs4) #create objects for 20% group 4 

#dd_compare(dd5,abs5) #create objects for 20% group 5
# Out:
# Topic Name: Direct For Education and Human Resources	Division Of Undergraduate Education
#
# Topics Represented by 20% group: 13
#
# Abstract 1 Distribution:
# [(1, 0.02278819110938889), (5, 0.10356565771623627), (6, 0.01115297258665332), (8, 0.051556126081401699), (10, 0.17131005422756262), (11, 0.20667136020346452), (12, 0.03746257605248586), (17, 0.054919892473400948), (18, 0.1428605300819582), (19, 0.057669804666250664), (23, 0.12627035014994323)]
#
# Abstract 2 Distribution:
# [(3, 0.058076664691727828), (5, 0.15306920177688377), (8, 0.01641617523094047), (10, 0.13450149094401251), (11, 0.10039572509518224), (12, 0.042460022330838815), (14, 0.085332020030134501), (17, 0.072152236315976143), (18, 0.042052951384748356), (19, 0.017729950911854406), (21, 0.14898163567232933), (23, 0.082601586781823069), (24, 0.025468074074911085)]
# <function matplotlib.pyplot.show>

# %%
from gensim import corpora, models, similarities 
from collections import defaultdict
import gensim
from bs4 import BeautifulSoup

file = open('cu_IDs.txt', 'r')
doc = file.readlines()

#All abstracts file
file1 = open('cu_tigers.txt','r') 
doc1 = file1.readlines()

#Doctorates and Divisions file
file3 = open('cu_doc_div.txt', 'r')
doc3 = file3.readlines()

#Doctorates and Divisions file
file4 = open('cu_doc_div2.txt', 'r')
doc4 = file4.readlines()

print(doc[4])
print(doc3[4])
print(doc1[4])
# Out:
# 1504619
#
# Direct For Education and Human Resources	Division Of Undergraduate Education
#
# This project will investigate the use of virtual reality technologies to create virtual field experiences for use in introductory geosciences classes Although field experiences are an important aspect of geoscience education there are few opportunities to provide physical world experiences to many undergraduate students due to access logistical and financial constraints Thus geoscience instructors must develop novel teaching and learning opportunities that closely approximate the information elements and environment students would find on a physical in-person field study The types of virtual experiences developed through this project while different from their physical corollaries will give learners the chance to engage with learning content and activities through multi-modal interactions in the virtual environment The use of virtualization tools will create opportunities that give geoscience educators access to interactive contextualized teaching materials and learners access to a space for exploration and discovery The development of virtual reality field experiences will also create a pathway for a diverse audience of students to encounter the earth sciences particularly those from underrepresented groups resource-limited institutions and majors traditionally not directly involved in the earth sciences Enhancing access to educational opportunities for these groups will aid in developing the engaged diverse and earth-science literate population that is needed to address societal needs in a complex and changing worldThe project will develop a virtual reality field-trip of the Grand Canyon that will be accessible to a wide audience in diverse educational settings Through the experience students will develop core geoscience concepts as they find and evaluate evidence that will help them piece together the geologic history of the region In the virtual experience students will apply their knowledge of rock and mineral properties build their understanding of spatial and temporal relationships between Earth processes learn how these relationships are recorded in the rock and ultimately synthesize their observations into a coherent geologic story that they will encapsulate in lay terms as a virtual brochure for the Canyon The project will also develop a virtual reality toolbox for earth science educators that will facilitate the future development of additional virtual field activities The project will utilize new innovations in the field of virtual reality eg Oculus Rift technology to provide geoscience educators the means to give every student a first-person virtual field experience The virtual field experiences will be designed to emphasize key aspects of geoscience learning (ie temporal thinking spatial thinking earth systems and field learning) and integrate the 'Big Ideas' in geoscience proposed by the Earth Science Literacy Initiative The specific learning activities that will be developed in the project are strongly grounded in the existing geoscience education STEM education and game-based learning literature and will utilize built-in learning analytics for improved assessment of student learning By addressing both the affective and cognitive routes to learning this approach holds promise to increase student engagement and concept retention in the classroom

# %%
read_words = open('stopwords.txt', 'r')        
r_words = read_words.readline()
print(r_words)
# Out:
# side up end was all than ever despite often large has have been there know provide near two well some offer much higher low each within about such one uses over being approach its but if can which used or no other may who details it an few many thus must their more also these find at on via with would on find from due for a of the and to in not them is that will be as they virtual how understanding lay into by both are aspects give every new use this make ways student high through university (1) (2) future by the algebraic problem problems involves using us could research so while between much research project projects our (ii) (iii) -- meeting meetings because we best module and specific middle change

# %%
from bs4 import BeautifulSoup
from gensim import corpora
from pprint import pprint 
from collections import defaultdict
import glob 

    

    
#Open files
item = open("2015/1511051.xml")
    
#Store Data
xml = item.read()
    
#Convert data to text 
soup = BeautifulSoup(xml,'xml')
    
soup.AbstractNarration.string
# Out:
# '1511051<br/>Amy<br/><br/>Currently, seawater reverse osmosis is the most commonly used desalination technology. Specifically, the blending of reverse osmosis desalinated water with single or multiple treated fresh waters drawn from other sources is a low-cost method to meet the demands of drinking water and to increase the concentration of some desired ions. Therefore, the objective of this project is to conduct a comprehensive and systematic study to examine the formation and speciation of reaction byproducts of disinfection and the toxicity changes of seawater reverse osmosis desalinated waters as a consequence of blending.<br/><br/>This is the first comprehensive research that combines a disinfection byproduct study on the formation, speciation, and factors affecting bromide/iodide incorporation with a toxicology study to determine possible toxicities on mammalian cells. In this study, the PIs propose to investigate: 1) the formation and speciation of brominated/iodinated disinfection byproducts in the presence of hydrophilic organic matter (e.g., algal organic matter, wastewater effluent organic matter, natural organic matter) of different origins in treated waters that are likely to be used for blending with seawater reverse osmosis permeate, 2) the effects of pH and temperature on the formation and speciation of brominated/iodinated disinfection byproducts, 3) the change in mammalian cell cytotoxicity and genotoxicity of waters from blending, and 4) the ability of total organic halide species and/or other individual brominated/iodinated disinfection byproducts to predict the cytotoxicity and genotoxicity of the blended waters based on a multiple regression. The project will be conducted in two phases: Phase 1, which entails a disinfection byproduct study on the formation, speciation, and factors affecting bromide/iodide incorporation under various mixing scenarios and using chlorine and chloramine for post-disinfection (i and ii); and Phase 2, which entails a toxicity study on mammalian cell cytotoxicity and genotoxicity of waters from blending and multiple regression analysis between total organic halide components and experimentally measured water toxicities (iii and iv). Educational components of the project will provide opportunities for undergraduate (e.g., Creative Inquiry Program at Clemson, UIUC WaterCamps program, the UIUC Global Safe Water Institute) and high school student research, including recruitment of underrepresented groups in scientific research.'
