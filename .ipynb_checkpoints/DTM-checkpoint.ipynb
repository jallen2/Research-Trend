# %%
import os, pickle 

path= "/home/jallen2/git/Research-Trend/sample"
sampleList= os.listdir(path)
myList=[]
for items in sampleList:
    if ".xml"in items:
        myList.append(items)
print(myList[0])
# Out:
# 0196500.xml

# %%
/home/jallen2/git/Research-Trend/sample

# %%
import os, pickle 
import glob
path= "sample"
myList = []
for items in glob.glob("sample/*.xml"):
    print(items)
    #open items first
    for line in items:
        if line.startswith("<rootTag>"):
            myList.append(items)
print(myList)

# %%
import glob
import xml.etree.ElementTree as et

global iDs, abstract 
iDs = []
abstract = []
def addAbstracttolist(abst):
    if not abst:
        abstract.append("N/A")
    else:
        abstract.append(abst)
def addIDtolist(ID):
    iDs.append(ID)
    
for items in glob.glob("sample/0*.xml"):
    data = open(items)
    str_data = data.read()
    print()
    xml_data = et.fromstring(str_data)
    print(xml_data)
    global award_list 
    award_list = xml_data.findall("Award")
    print(items.find("AwardID"))
#    addIDtolist(str(items.find("AwardID")))
#    addAbstracttolist(items.find("AbstractNarration").text)
   
    
for i in iDs:
    print(iDs[i]+":",abstract[i])
# Out:
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc56be58>
# -1
# <Element 'rootTag' at 0x2b15dc4d3f48>
# -1
# <Element 'rootTag' at 0x2b15dc4d34a8>
# -1
# <Element 'rootTag' at 0x2b15dc55c6d8>
# -1
# <Element 'rootTag' at 0x2b15dc56b778>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc4d3728>
# -1
# <Element 'rootTag' at 0x2b15dc55cdb8>
# -1
# <Element 'rootTag' at 0x2b15dc55c6d8>
# -1
# <Element 'rootTag' at 0x2b15dc56b908>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc4d3368>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc56b728>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc4d3868>
# -1
# <Element 'rootTag' at 0x2b15dc4d3368>
# -1
# <Element 'rootTag' at 0x2b15dc56b728>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc55ce08>
# -1
# <Element 'rootTag' at 0x2b15dc4d36d8>
# -1
# <Element 'rootTag' at 0x2b15dc4d3c28>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc55cea8>
# -1
# <Element 'rootTag' at 0x2b15dc55ce08>
# -1
# <Element 'rootTag' at 0x2b15dc4d3728>
# -1
# <Element 'rootTag' at 0x2b15dc584908>
# -1
# <Element 'rootTag' at 0x2b15dc584868>
# -1
# <Element 'rootTag' at 0x2b15dc55cef8>
# -1
# <Element 'rootTag' at 0x2b15dc56be58>
# -1
# <Element 'rootTag' at 0x2b15dc584a48>
# -1
# <Element 'rootTag' at 0x2b15dc584c28>
# -1
# <Element 'rootTag' at 0x2b15dc55cef8>
# -1
# <Element 'rootTag' at 0x2b15dc56be58>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc55c688>
# -1
# <Element 'rootTag' at 0x2b15dc584ef8>
# -1
# <Element 'rootTag' at 0x2b15dc584d68>
# -1
# <Element 'rootTag' at 0x2b15dc56b818>
# -1
# <Element 'rootTag' at 0x2b15dc55cea8>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc584cc8>
# -1
# <Element 'rootTag' at 0x2b15dc56bdb8>
# -1
# <Element 'rootTag' at 0x2b15dc56b728>
# -1
# <Element 'rootTag' at 0x2b15dc55cf48>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc56bc28>
# -1
# <Element 'rootTag' at 0x2b15dc56bb38>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc5845e8>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc56be58>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc56bb38>
# -1
# <Element 'rootTag' at 0x2b15dc584bd8>
# -1
# <Element 'rootTag' at 0x2b15dc584f98>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc56bb38>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc56b8b8>
# -1
# <Element 'rootTag' at 0x2b15dc584ef8>
# -1
# <Element 'rootTag' at 0x2b15dc5846d8>
# -1
# <Element 'rootTag' at 0x2b15dc55cea8>
# -1
# <Element 'rootTag' at 0x2b15dc521db8>
# -1
# <Element 'rootTag' at 0x2b15dc52d778>
# -1
# <Element 'rootTag' at 0x2b15dc56bdb8>
# -1
# <Element 'rootTag' at 0x2b15dc584c28>
# -1
# <Element 'rootTag' at 0x2b15dc584ae8>
# -1
# <Element 'rootTag' at 0x2b15dc4d30e8>
# -1
# <Element 'rootTag' at 0x2b15dc4d34a8>
# -1

# %%
import xml.etree.ElementTree as et
import glob 

global awards
awards=dict()

def addIDandAbs(ID,abstract):
    for i in awards:
        if i == ID:
            print("Error")
            return
    awards[ID] = abstract
    
def addtolist():
    for i in award_list:
        addIDandAbs(i.find("AwardID").text,i.find("AbstractNarration").text)    
#print(glob.glob("sample/0*.xml"))
for items in glob.glob("sample/*/*.xml"):
    item = open(items)
    str_data =  item.read()
    data = et.fromstring(str_data)
#    global award_list 
#    award_list = data.findall("Award")
#    for i in award_list:
#        addIDandAbs(i.find("AwardID").text,i.find("AbstractNarration").text)
    addIDandAbs(data.find("Award").find("AwardID").text,data.find("Award").find("Institution").find("Name").text)
for k, v in awards.items(): 
    sorted(awards.keys())
    print(k+":", v)
# Out:
# 0196566: SUNY at Buffalo
# 0196502: University of Maryland Biotechnology Institute
# 0196517: Georgia Tech Research Corporation
# 0196538: University of Oregon Eugene
# 0196508: University of Florida
# 0196514: Cornell University
# 0196560: SRI International
# 0196556: Duke University
# 0196551: University of Illinois at Urbana-Champaign
# 0196553: Wayne State University
# 0196532: University of Massachusetts Boston
# 0196569: University of New Mexico
# 0196530: West Chester University of Pennsylvania
# 0196565: University of Massachusetts Lowell Research Foundation
# 0196526: University of California-Santa Barbara
# 0196527: University of California-Berkeley
# 0196535: Western Washington University
# 0196510: University of Florida
# 0196520: University of Massachusetts Boston
# 0196555: University of California-Berkeley
# 0196544: University of California-Los Angeles
# 0196503: Yale University
# 0196500: University of California-Santa Barbara
# 0196536: University of Maryland College Park
# 0196541: University of Michigan Ann Arbor
# 0196511: Pennsylvania State Univ University Park
# 0196548: California State L A University Auxiliary Services Inc.
# 0196525: Pennsylvania State Univ University Park
# 0196540: Vanderbilt University
# 0196513: Washington University
# 0196519: Pennsylvania State Univ University Park
# 0196501: University of Tennessee Knoxville
# 0196537: University of South Florida
# 0196542: Indiana University
# 0196518: Colorado State University
# 0196563: Pennsylvania State Univ University Park
# 0196554: Virginia Commonwealth University
# 0196557: Florida International University
# 0196529: Arizona State University
# 0196568: Louisiana State University & Agricultural and Mechanical College
# 0196522: Pennsylvania State Univ University Park
# 0196505: Ramapo College of New Jersey
# 0196559: Mississippi State University
# 0196516: Emory University
# 0196534: University of Iowa
# 0196504: Carnegie-Mellon University
# 0196515: Oregon Health and Science University
# 0196512: California Institute of Technology
# 0196549: University of Minnesota-Twin Cities
# 0196561: Northern Arizona University
# 0196531: Indiana University
# 0196571: George Mason University
# 0196552: Stanford University
# 0196558: University of New Mexico
# 0196546: New York University
# 0196506: Northwestern University
# 0196547: University of Iowa
# 0196550: Michigan State University
# 0196567: Arizona State University
# 0196524: University of California-Irvine
# 0196562: University of California-Davis
# 0196509: University of Wisconsin-Madison
# 0196521: Bigelow Laboratory for Ocean Sciences
# 0196533: University of Maryland College Park
# 0196539: Luther College
# 0196564: University of Wisconsin-Eau Claire
# 0196507: University of Nevada Las Vegas
# 0196543: University of Massachusetts, Dartmouth
# 0196545: Stanford University
# 0196570: Pennsylvania State Univ University Park
# 0196528: University of Wisconsin-Madison
# 0196523: University of Miami
